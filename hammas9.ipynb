# %%
import pandas as pd

# %%
 dt = pd.read_csv("df_batting.csv")
dt
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#      runs  balls  4s  6s      SR out/not_out     match_id
# ...

# %%
data_shape = dt.shape
print("shape of data frame,",data_shape)
# Out:
# shape of data frame, (699, 11)

# %%
data_type = dt.dtypes
print("type of data \n",data_type)
# Out:
# type of data
#  match          object
# teamInnings    object
# battingPos      int64
# batsmanName    object
# runs            int64
# balls           int64
# 4s              int64
# 6s              int64
# SR             object
# out/not_out    object
# match_id       object
# dtype: object

# %%
data_info = dt.info()
print("information for data", data_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match        699 non-null    object
#  1   teamInnings  699 non-null    object
#  2   battingPos   699 non-null    int64
#  3   batsmanName  699 non-null    object
#  4   runs         699 non-null    int64
#  5   balls        699 non-null    int64
#  6   4s           699 non-null    int64
#  7   6s           699 non-null    int64
#  8   SR           699 non-null    object
#  9   out/not_out  699 non-null    object
#  10  match_id     699 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 60.2+ KB
# information for data None

# %%
missing_values = dt.isnull()
print("Missing Values \n", missing_values)
# Out:
# Missing Values
#       match  teamInnings  battingPos  batsmanName   runs  balls     4s     6s  \
# 0    False        False       False        False  False  False  False  False
# 1    False        False       False        False  False  False  False  False
# 2    False        False       False        False  False  False  False  False
# 3    False        False       False        False  False  False  False  False
# 4    False        False       False        False  False  False  False  False
# ..     ...          ...         ...          ...    ...    ...    ...    ...
# 694  False        False       False        False  False  False  False  False
# 695  False        False       False        False  False  False  False  False
# 696  False        False       False        False  False  False  False  False
# 697  False        False       False        False  False  False  False  False
# 698  False        False       False        False  False  False  False  False
#
# ...

# %%
missing_values = dt.isnull().sum()
print("Missing Values \n", missing_values)
# Out:
# Missing Values
#  match          0
# teamInnings    0
# battingPos     0
# batsmanName    0
# runs           0
# balls          0
# 4s             0
# 6s             0
# SR             0
# out/not_out    0
# match_id       0
# dtype: int64

# %%
summary_stats = dt.describe()
summary_stats_all = dt.describe(include='all')
print(summary_stats)
print(summary_stats_all)
# Out:
#        battingPos        runs       balls          4s          6s
# count  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     4.979971   15.978541   13.648069    1.300429    0.473534
# std      2.813628   18.709462   12.718093    1.834448    0.978465
# min      1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      3.000000    2.000000    4.000000    0.000000    0.000000
# 50%      5.000000    9.000000   10.000000    1.000000    0.000000
# 75%      7.000000   22.500000   19.000000    2.000000    1.000000
# max     11.000000  109.000000   64.000000   10.000000    8.000000
#                            match teamInnings  battingPos         batsmanName  \
# count                        699         699  699.000000                 699
# unique                        42          16         NaN                 200
# top     Pakistan Vs South Africa    Zimbabwe         NaN  Scott Edwards(c)â€
# ...

# %%
dt
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#      runs  balls  4s  6s      SR out/not_out     match_id
# ...

# %%
dt.head(10)
# Out:
#                   match teamInnings  battingPos             batsmanName  runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen     3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock     9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton    20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard    26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)    20
# 5  Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck    44
# 6  Namibia Vs Sri Lanka     Namibia           7             David Wiese     0
# 7  Namibia Vs Sri Lanka     Namibia           8                 JJ Smit    31
# 8  Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka     9
# 9  Namibia Vs Sri Lanka   Sri Lanka           2          Kusal Mendisâ€     6
#
#    balls  4s  6s      SR out/not_out     match_id
# 0      6   0   0   50.00         out  T20I # 1823
# ...

# %%
dt.loc[4,"batsmanName"]
# Out:
# 'Gerhard Erasmus(c)'

# %%
dt.loc[[4],["teamInnings","batsmanName","runs","balls"]]
# Out:
#   teamInnings         batsmanName  runs  balls
# 4     Namibia  Gerhard Erasmus(c)    20     24

# %%
dt.loc[[4,8],["teamInnings","batsmanName","runs","balls"]]
# Out:
#   teamInnings         batsmanName  runs  balls
# 4     Namibia  Gerhard Erasmus(c)    20     24
# 8   Sri Lanka     Pathum Nissanka     9     10

# %%
dt.iloc[[3,6,1],[1,3,4,5,9,10]]
# Out:
#   teamInnings    batsmanName  runs  balls out/not_out     match_id
# 3     Namibia  Stephan Baard    26     24         out  T20I # 1823
# 6     Namibia    David Wiese     0      1         out  T20I # 1823
# 1     Namibia  Divan la Cock     9      9         out  T20I # 1823

# %%
dt_1 = pd.read_csv("df_batting.csv",index_col=3)
dt_1
# Out:
#                                        match teamInnings  battingPos  runs  \
# batsmanName
# Michael van Lingen      Namibia Vs Sri Lanka     Namibia           1     3
# Divan la Cock           Namibia Vs Sri Lanka     Namibia           2     9
# Jan Nicol Loftie-Eaton  Namibia Vs Sri Lanka     Namibia           3    20
# Stephan Baard           Namibia Vs Sri Lanka     Namibia           4    26
# Gerhard Erasmus(c)      Namibia Vs Sri Lanka     Namibia           5    20
# ...                                      ...         ...         ...   ...
# Phil Salt                Pakistan Vs England     England           3    10
# Ben Stokes               Pakistan Vs England     England           4    52
# Harry Brook              Pakistan Vs England     England           5    20
# Moeen Ali                Pakistan Vs England     England           6    19
# Liam Livingstone         Pakistan Vs England     England           7     1
#
# ...

# %%
dt_1.drop("teamInnings", axis=1, inplace= True)

# %%
dt_1
# Out:
#                                        match  battingPos  runs  balls  4s  6s  \
# batsmanName
# Michael van Lingen      Namibia Vs Sri Lanka           1     3      6   0   0
# Divan la Cock           Namibia Vs Sri Lanka           2     9      9   1   0
# Jan Nicol Loftie-Eaton  Namibia Vs Sri Lanka           3    20     12   1   2
# Stephan Baard           Namibia Vs Sri Lanka           4    26     24   2   0
# Gerhard Erasmus(c)      Namibia Vs Sri Lanka           5    20     24   0   0
# ...                                      ...         ...   ...    ...  ..  ..
# Phil Salt                Pakistan Vs England           3    10      9   2   0
# Ben Stokes               Pakistan Vs England           4    52     49   5   1
# Harry Brook              Pakistan Vs England           5    20     23   1   0
# Moeen Ali                Pakistan Vs England           6    19     13   3   0
# Liam Livingstone         Pakistan Vs England           7     1      1   0   0
#
# ...

# %%
dt_2 = pd.read_csv("df_batting.csv")
dt_2
# Out:
#                     match teamInnings  battingPos             batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2           Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4           Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)
# ..                    ...         ...         ...                     ...
# 694   Pakistan Vs England     England           3               Phil Salt
# 695   Pakistan Vs England     England           4              Ben Stokes
# 696   Pakistan Vs England     England           5             Harry Brook
# 697   Pakistan Vs England     England           6               Moeen Ali
# 698   Pakistan Vs England     England           7        Liam Livingstone
#
#      runs  balls  4s  6s      SR out/not_out     match_id
# ...

# %%
dt_2.loc[1:20,:"balls"]
# Out:
#                     match teamInnings  battingPos                 batsmanName  \
# 1    Namibia Vs Sri Lanka     Namibia           2               Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3      Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4               Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5          Gerhard Erasmus(c)
# 5    Namibia Vs Sri Lanka     Namibia           6                Jan Frylinck
# 6    Namibia Vs Sri Lanka     Namibia           7                 David Wiese
# 7    Namibia Vs Sri Lanka     Namibia           8                     JJ Smit
# 8    Namibia Vs Sri Lanka   Sri Lanka           1             Pathum Nissanka
# 9    Namibia Vs Sri Lanka   Sri Lanka           2              Kusal Mendisâ€
# 10   Namibia Vs Sri Lanka   Sri Lanka           3         Dhananjaya de Silva
# 11   Namibia Vs Sri Lanka   Sri Lanka           4        Danushka Gunathilaka
# ...

# %%
dt_2.iloc[1:20,:5]
# Out:
#                     match teamInnings  battingPos                 batsmanName  \
# 1    Namibia Vs Sri Lanka     Namibia           2               Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3      Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4               Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5          Gerhard Erasmus(c)
# 5    Namibia Vs Sri Lanka     Namibia           6                Jan Frylinck
# 6    Namibia Vs Sri Lanka     Namibia           7                 David Wiese
# 7    Namibia Vs Sri Lanka     Namibia           8                     JJ Smit
# 8    Namibia Vs Sri Lanka   Sri Lanka           1             Pathum Nissanka
# 9    Namibia Vs Sri Lanka   Sri Lanka           2              Kusal Mendisâ€
# 10   Namibia Vs Sri Lanka   Sri Lanka           3         Dhananjaya de Silva
# 11   Namibia Vs Sri Lanka   Sri Lanka           4        Danushka Gunathilaka
# ...

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print("Array:", arr)
# Out:
# Array: [1 2 3 4 5]

# %% [markdown]
# ### Addition ---->

# %%
add_arr = arr + 2
add_arr
# Out:
# array([3, 4, 5, 6, 7])

# %% [markdown]
# ### Subtraction ---->

# %%
sub_arr = arr - 2
sub_arr
# Out:
# array([-1,  0,  1,  2,  3])

# %% [markdown]
# ### Multiplication ---->

# %%
mul_arr = arr * 2
mul_arr
# Out:
# array([ 2,  4,  6,  8, 10])

# %% [markdown]
# ### Division ---->

# %%
div_arr = arr / 2
div_arr
# Out:
# array([0.5, 1. , 1.5, 2. , 2.5])

# %% [markdown]
# ### Indexing & Slicing ---->

# %%
element1 = arr[1]
element2 = arr[2]

print("Element_1:", element1)
print("Element_2:", element2)

slice = arr[2:4]
print("Slicing Array:", slice)
# Out:
# Element_1: 2
# Element_2: 3
# Slicing Array: [3 4]

# %% [markdown]
# ### Reshaping Array ---->

# %%
reshape_arr = arr.reshape(5,1)
print(reshape_arr)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %% [markdown]
# ### Transposing Matrices ---->

# %%
transpose_arr = reshape_arr.T
print("Transposed Array: ", transpose_arr)
# Out:
# Transposed Array:  [[1 2 3 4 5]]

# %% [markdown]
# ### Statistical Functions ---->

# %%
mean = np.mean(arr)
mean
# Out:
# 3.0

# %%
median = np.median(arr)
median
# Out:
# 3.0

# %%
std_dev = np.std(arr)
std_dev
# Out:
# 1.4142135623730951

# %%
var = np.var(arr)
var
# Out:
# 2.0

# %% [markdown]
# ### Data Types In Arrays ---->

# %%
int_arr = np.array(arr, dtype=int)
print("Integer: ",int_arr)
# Out:
# Integer:  [1 2 3 4 5]

# %%
float_arr = np.array(arr, dtype=float)
print("float:",float_arr)
# Out:
# float: [1. 2. 3. 4. 5.]

# %%
bool_arr= np.array(arr, dtype=bool)
print("Boolean: ",bool_arr)
# Out:
# Boolean:  [ True  True  True  True  True]

# %%
str_arr = np.array(arr, dtype=str)
print("String: ",str_arr)
# Out:
# String:  ['1' '2' '3' '4' '5']

# %% [markdown]
# ### Concatenating Array ---->

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])
concatenated_arr = np.concatenate((arr1, arr2))
print("Concatenated Array:", concatenated_arr)
# Out:
# Concatenated Array: [1 2 3 4 5 6]

# %% [markdown]
# ### Sorting Arrays ---->

# %%
unsorted_array = np.array([3, 1, 2, 5, 4])
sorted_array_asc = np.sort(unsorted_array)  
sorted_array_desc = np.sort(unsorted_array)[::-1]  

print("Sorted Array (Ascending):", sorted_array_asc)
print("Sorted Array (Descending):", sorted_array_desc)
# Out:
# Sorted Array (Ascending): [1 2 3 4 5]
# Sorted Array (Descending): [5 4 3 2 1]

# %% [markdown]
# ### Assignments#9 Complete.....!!!
